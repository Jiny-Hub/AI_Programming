# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(10)
plt.plot(x**2)

# %%
fig, ax = plt.subplots (2,2)

x = np.random.randn(100)
y = np.random.randn(100)
ax[0,0].scatter(x,y)

x = np.arange(10)
y = np.random.uniform(1,10,10)
ax[0,1].bar(x,y)

x = np.linspace(0,10,100)
y = np.cos(x)
ax[1,0].plot(x,y)

z = np.random.uniform(0,1,(5,5))
ax[1,1].imshow(z)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig, ax = plt.subplots(3,3)

grid = gridspec.gridspec (3,3, wspace=0.4, hspace=0.3)
x = np.random.randn(100)
y = np.random.randn(100)
plt.subplot(grid[0.:]).scatter(x,y)

x = np.linspace (0,10,100)
y = np.cos(x)
plt.subplot(grid[2,0]).plot(x,y,color='g')

x = np.arange(10)
y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2,1]).bar(x,y)

z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:,2]).imshow(z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b4dffb5aad61> in <cell line: 7>()
#       5 fig, ax = plt.subplots(3,3)
#       6
# ----> 7 grid = gridspec.gridspec (3,3, wspace=0.4, hspace=0.3)
#       8 x = np.random.randn(100)
#       9 y = np.random.randn(100)
#
# AttributeError: module 'matplotlib.gridspec' has no attribute 'gridspec'

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig, ax = plt.subplots(3,3)

grid = gridspec.GridSpec(3,3, wspace=0.4, hspace=0.3)
x = np.random.randn(100)
y = np.random.randn(100)
plt.subplot(grid[0,:]).scatter(x,y)

x = np.linspace (0,10,100)
y = np.cos(x)
plt.subplot(grid[2,0]).plot(x,y,color='g')

x = np.arange(10)
y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2,1]).bar(x,y)

z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:,2]).imshow(z)
# Out:
# <ipython-input-11-724c666f2d90>:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0,:]).scatter(x,y)
# <ipython-input-11-724c666f2d90>:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,0]).plot(x,y,color='g')
# <ipython-input-11-724c666f2d90>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,1]).bar(x,y)
# <ipython-input-11-724c666f2d90>:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1:,2]).imshow(z)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig, ax = plt.subplots(3,3)

grid = gridspec.GridSpec(3,3, wspace=0.4, hspace=0.3)
x = np.random.randn(100)
y = np.random.randn(100)
plt.subplot(grid[0,:]).scatter(x,y)

x = np.linspace (0,10,100)
y = np.cos(x)
plt.subplot(grid[2,0]).plot(x,y,color='g')

x = np.arange(10)
y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2,1]).bar(x,y)

z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:,2]).imshow(z)

x = np.arange(10)
y = x
plt.subplot(grid[1,:2]).plot(x,y)
# Out:
# <ipython-input-12-52a0e6d44549>:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0,:]).scatter(x,y)
# <ipython-input-12-52a0e6d44549>:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,0]).plot(x,y,color='g')
# <ipython-input-12-52a0e6d44549>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,1]).bar(x,y)
# <ipython-input-12-52a0e6d44549>:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1:,2]).imshow(z)
# <ipython-input-12-52a0e6d44549>:25: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1,:2]).plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig, ax = plt.subplots(3,3)

grid = gridspec.GridSpec(3,3, wspace=0.4, hspace=0.3)
x = np.random.randn(100)
y = np.random.randn(100)
plt.subplot(grid[0,:]).scatter(x,y)

x = np.linspace (0,10,100)
y = np.cos(x)
plt.subplot(grid[2,0]).plot(x,y,color='g')

x = np.arange(10)
y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2,1]).bar(x,y)

z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:,2]).imshow(z)

x = np.arange(1, 4.5, 0.5)
y = x
plt.subplot(grid[1,:2]).plot(x,y,color='r', linewidth=2)
# Out:
# <ipython-input-16-ea064dd1d2b8>:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0,:]).scatter(x,y)
# <ipython-input-16-ea064dd1d2b8>:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,0]).plot(x,y,color='g')
# <ipython-input-16-ea064dd1d2b8>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,1]).bar(x,y)
# <ipython-input-16-ea064dd1d2b8>:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1:,2]).imshow(z)
# <ipython-input-16-ea064dd1d2b8>:25: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1,:2]).plot(x,y,color='r')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig, ax = plt.subplots(3,3)

grid = gridspec.GridSpec(3,3, wspace=0.4, hspace=0.3)
x = np.random.randn(100)
y = np.random.randn(100)
plt.subplot(grid[0,:]).scatter(x,y)

x = np.linspace (0,10,100)
y = np.cos(x)
plt.subplot(grid[2,0]).plot(x,y,color='g')

x = np.arange(10)
y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2,1]).bar(x,y)

z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:,2]).imshow(z)

x = np.arange(1, 4.5, 0.5)
y = x
plt.subplot(grid[1,:2]).plot(x,y,color='r', linewidth=2)
# Out:
# <ipython-input-17-9502c352d704>:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0,:]).scatter(x,y)
# <ipython-input-17-9502c352d704>:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,0]).plot(x,y,color='g')
# <ipython-input-17-9502c352d704>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,1]).bar(x,y)
# <ipython-input-17-9502c352d704>:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1:,2]).imshow(z)
# <ipython-input-17-9502c352d704>:25: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1,:2]).plot(x,y,color='r', linewidth=2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig, ax = plt.subplots(3,3)

grid = gridspec.GridSpec(3,3, wspace=0.4, hspace=0.3)
x = np.random.randn(100)
y = np.random.randn(100)
plt.subplot(grid[0,:]).scatter(x,y)

x = np.linspace (0,10,100)
y = np.cos(x)
plt.subplot(grid[2,0]).plot(x,y,color='g')

x = np.arange(10)
y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2,1]).bar(x,y)

z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:,2]).imshow(z)

x = np.arange(1, 4.5, 0.5)
y = x
plt.subplot(grid[1,:2]).plot(x,y,'r:',linewidth=2)
# Out:
# <ipython-input-18-32718ada4355>:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0,:]).scatter(x,y)
# <ipython-input-18-32718ada4355>:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,0]).plot(x,y,color='g')
# <ipython-input-18-32718ada4355>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2,1]).bar(x,y)
# <ipython-input-18-32718ada4355>:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1:,2]).imshow(z)
# <ipython-input-18-32718ada4355>:25: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1,:2]).plot(x,y,'r:',linewidth=2)
