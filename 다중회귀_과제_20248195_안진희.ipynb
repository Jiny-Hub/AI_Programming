# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

m = 100
x = 8 * np.random.rand(m,1) - 4
y = 0.5 * x ** 2 + 0.5 * 2 * x + 1 + np.random.randn(m,1)

poly_features = PolynomialFeatures (degree = 2, include_bias = False)
x_poly = poly_features.fit_transform(x)
regr = LinearRegression()
regr.fit(x_poly,y)

print('다항 회귀 모델의 점수 =', regr.score(x_poly,y), round(3))
print('다항 회귀 모델의 계수=', regr.coef_, '절편=', regr.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.9219148739720496 3
# 다항 회귀 모델의 계수= [[1.0717422 0.4918585]] 절편= [1.06032873]

# %%
domain = np.linspace (-4,4,50).reshape(-1,1)
domain2 = poly_features.fit_transform(domain)

plt.figure(figsize=(6,4))
y_predict = regr.predict(domain2)

plt.scatter(x,y)
plt.plot(domain, y_predict, color='r', linewidth=4)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

m = 50  #산점도 값을 50개로 수정
x = 8 * np.random.rand(m,1) - 4
y = 0.5 * x ** 2 + 0.5 * 2 * x + 1 + np.random.randn(m,1)

poly_features = PolynomialFeatures (degree = 2, include_bias = False)
x_poly = poly_features.fit_transform(x)
regr = LinearRegression()
regr.fit(x_poly,y)

print('다항 회귀 모델의 점수 =', regr.score(x_poly,y), round(3))
print('다항 회귀 모델의 계수=', regr.coef_, '절편=', regr.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.9398911012675218 3
# 다항 회귀 모델의 계수= [[1.04846026 0.51528751]] 절편= [0.84508424]

# %%
domain = np.linspace (-4,4,50).reshape(-1,1)
domain2 = poly_features.fit_transform(domain)

plt.figure(figsize=(5,3)) #그림의 크기를 5,3인치로 수정
y_predict = regr.predict(domain2)

plt.scatter(x,y)
plt.plot(domain, y_predict, color='yellow', linewidth=3) #선의 색깔을 노란색, 굵기를 3으로 수정
